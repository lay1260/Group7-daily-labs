# %%
import pandas as pd
from pandas import DataFrame
import numpy as np


primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np


primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1=primitive_data.dropna(how='any')
primitive_data_1
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np


primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1=primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
data_after_filter_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np


primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1=primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
# data_after_filter_2
data_before_sample=data_after_filter_2
columns=data_before_sample.columns
weight_sample=data_before_sample.copy()
weight_sample['weight']=0
for i in weight_sample.index:
    if weight_sample.at[i,'to_level']=='一般节点':
        weight=1
    else:
        weight=5
    weight_sample.at[i,'weight']=weight

weight_sample_finish=weight_sample.sample(n=50,weights='weight')
#data_before_sample=data_before_sample[columns]
# weight_sample_finish=weight_sample[columns]
weight_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 578         63         70        通辽       一般节点     235     1749      北京
# 95         474        359       哈尔滨       一般节点    2050      502     石家庄
# 118        474       1238       哈尔滨       一般节点    1756     1008      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 330         96        336      呼和浩特       一般节点    1756     1106      北京
# 304         63        230        通辽       一般节点    3227       77      济南
# 544         63         54        通辽       一般节点    2050      336     石家庄
# 416        591         60        绥化       一般节点     180       52    呼和浩特
# 393        474       1238       哈尔滨       一般节点    1997      122      天津
# 353        180        188      呼和浩特       一般节点    1536     2274      广州
# 119        474       1246       哈尔滨       一般节点    3227      705      济南
# 133        591         13        绥化       一般节点   36422      324      天津
# 449        787        316        玉溪       一般节点   36422      394      天津
# 942      36036         52        长春       一般节点    2050      272     石家庄
# 339        180         18      呼和浩特       一般节点      47      241      通辽
# 540         47        427        通辽       一般节点    2549     1430      沈阳
# 1059        47        252        通辽       一般节点    1997      250      天津
# 355        180        200      呼和浩特       一般节点    1536     2309      广州
# 547         63         62        通辽       一般节点    1756     1067      北京
# 286         47        259        通辽       一般节点    4561     1087      成都
# 682         63         12        通辽       一般节点    3227      103      济南
# 407        591         11        绥化       一般节点     235      112      北京
# 280         47        243        通辽       一般节点    3213      562      重庆
# 326         96        156      呼和浩特       一般节点    4561     1031      成都
# 371        474        360       哈尔滨       一般节点    3227      530      济南
# 434        591       1250        绥化       一般节点    3227      468      济南
# 307         63        282        通辽       一般节点    1756       18      北京
# 176        787        324        玉溪       一般节点    1536     1941      广州
# 312         96        108      呼和浩特       一般节点    2841      117      郑州
# 573      36036         20        长春       一般节点     235     1621      北京
# 302         63        224        通辽       一般节点    1257      498      上海
# 98         474        417       哈尔滨       一般节点    1997       41      天津
# 138        591         27        绥化       一般节点    3443      117      青岛
# 301         63         74        通辽       一般节点    1756      469      北京
# 489         47        242        通辽       一般节点    2194      406      唐山
# 114        474        682       哈尔滨       一般节点    1536      585      广州
# 0           47         71        通辽       一般节点    1756      585      北京
# 381        474        475       哈尔滨       一般节点    2473      941      吉林
# 599        474        672       哈尔滨       一般节点    2050      336     石家庄
# 554         63        232        通辽       一般节点    3443      186      青岛
# 412        591         23        绥化       一般节点    2701       71      大连
# 924       2473       1043        吉林       一般节点      47      427      通辽
# 113        474        678       哈尔滨       一般节点    1997      124      天津
# 367        180        272      呼和浩特       一般节点     474      472     哈尔滨
# 667      36539       1140        杭州       一般节点    3227      781      济南
# 428        591       1028        绥化       一般节点   36422      230      天津
# 121        474       1269       哈尔滨       一般节点    2549     1430      沈阳
# 291         47        427        通辽       一般节点    3227      766      济南
# 115        474        683       哈尔滨       一般节点    1997       84      天津
# 31          63        278        通辽       一般节点     235     1649      北京
#
#      to_level      traffic     bandwidth  weight
# 578      网络核心  50871621460  1.000000e+11       5
# 95       网络核心  51299508559  1.000000e+11       5
# 118      网络核心  51270474683  1.000000e+11       5
# 2        网络核心  49453581081  1.000000e+11       5
# 330      网络核心  51277669375  1.000000e+11       5
# 304      网络核心  50504074996  1.000000e+11       5
# 544      网络核心  51911829933  1.000000e+11       5
# 416      一般节点  50126205393  1.000000e+11       1
# 393      网络核心  49693039378  1.000000e+11       5
# 353      网络核心  50649912010  1.000000e+11       5
# 119      网络核心  50954049859  1.000000e+11       5
# 133      网络核心  50085514419  1.000000e+11       5
# 449      网络核心  50880826227  1.000000e+11       5
# 942      网络核心  49916177327  1.000000e+11       5
# 339      一般节点  51793025548  1.000000e+11       1
# 540      网络核心  50264080533  1.000000e+11       5
# 1059     网络核心  50358481161  1.000000e+11       5
# 355      网络核心  49873632464  1.000000e+11       5
# 547      网络核心  49632977575  1.000000e+11       5
# 286      网络核心  49068568496  1.000000e+11       5
# 682      网络核心  52079990489  1.000000e+11       5
# 407      网络核心  50766117914  1.000000e+11       5
# 280      网络核心  49512830312  1.000000e+11       5
# 326      网络核心  50272713910  1.000000e+11       5
# 371      网络核心  49027966353  1.000000e+11       5
# 434      网络核心  50478302588  1.000000e+11       5
# 307      网络核心  49252024885  1.000000e+11       5
# 176      网络核心  48712502205  1.000000e+11       5
# 312      网络核心  48086467232  1.000000e+11       5
# 573      网络核心  50173217899  1.000000e+11       5
# 302      网络核心  50870996562  1.000000e+11       5
# 98       网络核心  51874083489  1.000000e+11       5
# 138      网络核心  49213859972  1.000000e+11       5
# 301      网络核心  49663523668  1.000000e+11       5
# 489      网络核心  47826329156  1.000000e+11       5
# 114      网络核心  50262691915  1.000000e+11       5
# 0        网络核心  49636052613  1.000000e+11       5
# 381      一般节点  49402590822  1.000000e+11       1
# 599      网络核心  51340689424  1.000000e+11       5
# 554      网络核心  50311811210  1.000000e+11       5
# 412      网络核心  50009822342  1.000000e+11       5
# 924      一般节点  50311375989  1.000000e+11       1
# 113      网络核心  49044545927  1.000000e+11       5
# 367      一般节点  49398387251  1.000000e+11       1
# 667      网络核心  49721314562  1.000000e+11       5
# 428      网络核心  50678848280  1.000000e+11       5
# 121      网络核心  50312177853  1.000000e+11       5
# 291      网络核心  49389391674  1.000000e+11       5
# 115      网络核心  49446798762  1.000000e+11       5
# 31       网络核心  50882530855  1.000000e+11       5

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np


primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1=primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
# data_after_filter_2
data_before_sample=data_after_filter_2
random_sample=data_before_sample
random_sample_finish=random_sample.sample(n=50)
random_sample_finish=random_sample_finish[columns]
random_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 705         47        242        通辽       一般节点      63      286      通辽
# 441        591       1300        绥化       一般节点      47      252      通辽
# 129        474       1410       哈尔滨       一般节点    4069     1205      宁波
# 134        591         15        绥化       一般节点    1385     1490      广州
# 455        787        360        玉溪       一般节点    2701       71      大连
# 352        180         98      呼和浩特       一般节点    1997      190      天津
# 381        474        475       哈尔滨       一般节点    2473      941      吉林
# 495         47        258        通辽       一般节点     235     1958      北京
# 793        180         20      呼和浩特       一般节点     474      359     哈尔滨
# 318         96        124      呼和浩特       一般节点    1536     1891      广州
# 339        180         18      呼和浩特       一般节点      47      241      通辽
# 146        591        502        绥化       一般节点    1129      546      上海
# 138        591         27        绥化       一般节点    3443      117      青岛
# 353        180        188      呼和浩特       一般节点    1536     2274      广州
# 173        787        307        玉溪       一般节点    4953      686      贵阳
# 277         47        240        通辽       一般节点    3213      246      重庆
# 180        787        360        玉溪       一般节点    3615      191      长沙
# 118        474       1238       哈尔滨       一般节点    1756     1008      北京
# 89         180        256      呼和浩特       一般节点    1129      171      上海
# 1093       591        586        绥化       一般节点    1536       86    鄂尔多斯
# 785        180        252      呼和浩特       一般节点     180      252    呼和浩特
# 295         63         54        通辽       一般节点    3227      493      济南
# 19          63         12        通辽       一般节点     180      252    呼和浩特
# 337         96        460      呼和浩特       一般节点    2050      313     石家庄
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# 80         180        200      呼和浩特       一般节点    2701      300      大连
# 530         47        249        通辽       一般节点    2473      799      吉林
# 722       4360        468        南京       一般节点    3443      117      青岛
# 2           47        240        通辽       一般节点    1756      802      北京
# 307         63        282        通辽       一般节点    1756       18      北京
# 94         180        485      呼和浩特       一般节点   36422      102      天津
# 438        591       1284        绥化       一般节点    2841      237      郑州
# 65         180         20      呼和浩特       一般节点      63      224      通辽
# 281         47        249        通辽       一般节点    1536     1882      广州
# 449        787        316        玉溪       一般节点   36422      394      天津
# 63         180         10      呼和浩特       一般节点    2994      270      洛阳
# 804        180        264      呼和浩特       一般节点     474      475     哈尔滨
# 913       2473        799        吉林       一般节点      47      243      通辽
# 432        591       1106        绥化       一般节点    3227      781      济南
# 84         180        214      呼和浩特       一般节点    2701      135      大连
# 289         47        417        通辽       一般节点    3615      191      长沙
# 114        474        682       哈尔滨       一般节点    1536      585      广州
# 881        591        586        绥化       一般节点    1997       39      天津
# 898       2473        946        吉林       一般节点    2050      331     石家庄
# 317         96        123      呼和浩特       一般节点    2360      263      太原
# 395        474       1259       哈尔滨       一般节点    2549      835      沈阳
# 93         180        276      呼和浩特       一般节点   36272      235      太原
# 391        474       1227       哈尔滨       一般节点    2549      839      沈阳
# 331         96        346      呼和浩特       一般节点    1756     1128      北京
# 283         47        251        通辽       一般节点    1257      177      上海
#
#      to_level      traffic     bandwidth
# 705      一般节点  49144860439  1.000000e+11
# 441      一般节点  50817586398  1.000000e+11
# 129      一般节点  46523775334  1.000000e+11
# 134      网络核心  49228307349  1.000000e+11
# 455      网络核心  50222195150  1.000000e+11
# 352      网络核心  48859748771  1.000000e+11
# 381      一般节点  49402590822  1.000000e+11
# 495      网络核心  48574009525  1.000000e+11
# 793      一般节点  50601340670  1.000000e+11
# 318      网络核心  49479386359  1.000000e+11
# 339      一般节点  51793025548  1.000000e+11
# 146      网络核心  49465128399  1.000000e+11
# 138      网络核心  49213859972  1.000000e+11
# 353      网络核心  50649912010  1.000000e+11
# 173      一般节点  49399787960  1.000000e+11
# 277      网络核心  47105527982  1.000000e+11
# 180      一般节点  49629725686  1.000000e+11
# 118      网络核心  51270474683  1.000000e+11
# 89       网络核心  49512421445  1.000000e+11
# 1093     网络核心  47929885030  1.000000e+11
# 785      一般节点  47786098667  1.000000e+11
# 295      网络核心  49566827928  1.000000e+11
# 19       一般节点  49290094443  1.000000e+11
# 337      网络核心  50175772267  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# 80       网络核心  51884294458  1.000000e+11
# 530      一般节点  49803820036  1.000000e+11
# 722      网络核心  49458752996  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 307      网络核心  49252024885  1.000000e+11
# 94       网络核心  52460156321  1.000000e+11
# 438      网络核心  49402368215  1.000000e+11
# 65       一般节点  50551711152  1.000000e+11
# 281      网络核心  47584217074  1.000000e+11
# 449      网络核心  50880826227  1.000000e+11
# 63       网络核心  50401714739  1.000000e+11
# 804      一般节点  49012460413  1.000000e+11
# 913      一般节点  50993016382  1.000000e+11
# 432      网络核心  48568999606  1.000000e+11
# 84       网络核心  48901190886  1.000000e+11
# 289      一般节点  50099712071  1.000000e+11
# 114      网络核心  50262691915  1.000000e+11
# 881      网络核心  49268870810  1.000000e+11
# 898      网络核心  50778035219  1.000000e+11
# 317      网络核心  50500915133  1.000000e+11
# 395      网络核心  49504676343  1.000000e+11
# 93       网络核心  51775514286  1.000000e+11
# 391      网络核心  51028242209  1.000000e+11
# 331      网络核心  49834736741  1.000000e+11
# 283      网络核心  49380930804  1.000000e+11

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1=primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
# data_after_filter_2
data_before_sample=data_after_filter_2
ybjd=data_before_sample.loc[data_before_sample['to_level']=='一般节点']
wlhx=data_before_sample.loc[data_before_sample['to_level']=='网络核心']
after_sample=pd.concat([ybjd.sample(17),wlhx.sample(33)])
after_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 13          47        314        通辽       一般节点      96      152    呼和浩特
# 151        591        586        绥化       一般节点     180      192    呼和浩特
# 110        474        672       哈尔滨       一般节点      47      242      通辽
# 334         96        391      呼和浩特       一般节点      96      120    呼和浩特
# 180        787        360        玉溪       一般节点    3615      191      长沙
# 542         63         10        通辽       一般节点    4360      472      南京
# 61          96        407      呼和浩特       一般节点    4069     1196      宁波
# 445        787         60        玉溪       一般节点      47      314      通辽
# 19          63         12        通辽       一般节点     180      252    呼和浩特
# 780         96        391      呼和浩特       一般节点     180      205    呼和浩特
# 441        591       1300        绥化       一般节点      47      252      通辽
# 541         63          6        通辽       一般节点    2473     1043      吉林
# 770        474        672       哈尔滨       一般节点     180       42    呼和浩特
# 743       4069       1195        宁波       一般节点      96      134    呼和浩特
# 59          96        391      呼和浩特       一般节点      47      417      通辽
# 583       2473        946        吉林       一般节点   36539     1146      杭州
# 453        787        326        玉溪       一般节点     180       20    呼和浩特
# 420        591        100        绥化       一般节点     235      112      北京
# 131        474       1473       哈尔滨       一般节点    2549     1461      沈阳
# 98         474        417       哈尔滨       一般节点    1997       41      天津
# 58          96        383      呼和浩特       一般节点    5242      783      西安
# 449        787        316        玉溪       一般节点   36422      394      天津
# 18          63         10        通辽       一般节点     235      106      北京
# 384        474        671       哈尔滨       一般节点    1756      776      北京
# 357        180        205      呼和浩特       一般节点    2360      341      太原
# 287         47        260        通辽       一般节点    3213      597      重庆
# 543         63         12        通辽       一般节点    2549     1570      沈阳
# 60          96        399      呼和浩特       一般节点    1756     1117      北京
# 450        787        317        玉溪       一般节点     235      112      北京
# 31          63        278        通辽       一般节点     235     1649      北京
# 415        591         56        绥化       一般节点   36422      230      天津
# 77         180         98      呼和浩特       一般节点    1129      910      上海
# 52          96        157      呼和浩特       一般节点    2050      443     石家庄
# 317         96        123      呼和浩特       一般节点    2360      263      太原
# 1           47         74        通辽       一般节点    1756      776      北京
# 16          47        427        通辽       一般节点    1997      213      天津
# 395        474       1259       哈尔滨       一般节点    2549      835      沈阳
# 1059        47        252        通辽       一般节点    1997      250      天津
# 84         180        214      呼和浩特       一般节点    2701      135      大连
# 608         96        152      呼和浩特       一般节点    1385     1490      广州
# 452        787        325        玉溪       一般节点    2701      181      大连
# 417        591         64        绥化       一般节点    1257      560      上海
# 717       2473       1043        吉林       一般节点   36422      324      天津
# 143        591         96        绥化       一般节点    3443      101      青岛
# 335         96        399      呼和浩特       一般节点    1756      273      北京
# 385        474        672       哈尔滨       一般节点    1756      802      北京
# 574         63         12        通辽       一般节点    2994      430      洛阳
# 162        591       1274        绥化       一般节点    1129      203      上海
# 994         63          6        通辽       一般节点    2701      135      大连
# 120        474       1259       哈尔滨       一般节点    3227      787      济南
#
#      to_level      traffic     bandwidth
# 13       一般节点  50161220081  1.000000e+11
# 151      一般节点  49061517661  1.000000e+11
# 110      一般节点  51555817613  1.000000e+11
# 334      一般节点  51609945530  1.000000e+11
# 180      一般节点  49629725686  1.000000e+11
# 542      一般节点  49716409605  1.000000e+11
# 61       一般节点  49745162804  1.000000e+11
# 445      一般节点  49484495071  1.000000e+11
# 19       一般节点  49290094443  1.000000e+11
# 780      一般节点  50103206178  1.000000e+11
# 441      一般节点  50817586398  1.000000e+11
# 541      一般节点  48954016072  1.000000e+11
# 770      一般节点  51263599555  1.000000e+11
# 743      一般节点  50099141709  1.000000e+11
# 59       一般节点  51570663870  1.000000e+11
# 583      一般节点  50631070410  1.000000e+11
# 453      一般节点  51285240797  1.000000e+11
# 420      网络核心  51157112955  1.000000e+11
# 131      网络核心  53304989080  1.000000e+11
# 98       网络核心  51874083489  1.000000e+11
# 58       网络核心  50609333179  1.000000e+11
# 449      网络核心  50880826227  1.000000e+11
# 18       网络核心  52195591947  1.000000e+11
# 384      网络核心  51647234796  1.000000e+11
# 357      网络核心  50595793729  1.000000e+11
# 287      网络核心  50581039842  1.000000e+11
# 543      网络核心  50729523051  1.000000e+11
# 60       网络核心  50243694923  1.000000e+11
# 450      网络核心  48443015075  1.000000e+11
# 31       网络核心  50882530855  1.000000e+11
# 415      网络核心  47741796615  1.000000e+11
# 77       网络核心  50330801190  1.000000e+11
# 52       网络核心  50096366926  1.000000e+11
# 317      网络核心  50500915133  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 16       网络核心  48476552334  1.000000e+11
# 395      网络核心  49504676343  1.000000e+11
# 1059     网络核心  50358481161  1.000000e+11
# 84       网络核心  48901190886  1.000000e+11
# 608      网络核心  50846379751  1.000000e+11
# 452      网络核心  49891276242  1.000000e+11
# 417      网络核心  50045645266  1.000000e+11
# 717      网络核心  50594312992  1.000000e+11
# 143      网络核心  51199279798  1.000000e+11
# 335      网络核心  49011328602  1.000000e+11
# 385      网络核心  50199756109  1.000000e+11
# 574      网络核心  49165115912  1.000000e+11
# 162      网络核心  49321244844  1.000000e+11
# 994      网络核心  50680536460  1.000000e+11
# 120      网络核心  49591440488  1.000000e+11

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1 = primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter = primitive_data_1
data_after_filter_1 = data_before_filter.loc[data_before_filter["traffic"] != 0]
data_after_filter_2 = data_after_filter_1.loc[data_after_filter_1["from_level"] == '一般节点']
# data_after_filter_2
data_before_sample = data_after_filter_2

def systematic_sampling(data, sample_size, random_start=True):
    n = len(data)
    if n == 0:
        return pd.DataFrame()
    k = n // sample_size
    if k == 0:
        k = 1 
    if random_start:
        start = np.random.randint(0, k)
    else:
        start = 0
    indices = []
    for i in range(sample_size):
        index = start + i * k
        if index < n: 
            indices.append(index)
        else:
            break
    return data.iloc[indices].copy().reset_index(drop=True)

sample_size = 50 
systematic_sample = systematic_sampling(data_before_sample, sample_size)
systematic_sample
# Out:
#     from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0         47        242        通辽       一般节点     474      672     哈尔滨
# 1         47        425        通辽       一般节点    1756     1018      北京
# 2         63         74        通辽       一般节点    2701      181      大连
# 3         96        108      呼和浩特       一般节点    2360      236      太原
# 4         96        141      呼和浩特       一般节点     474      422     哈尔滨
# 5         96        391      呼和浩特       一般节点      47      417      通辽
# 6        180         36      呼和浩特       一般节点    2194      406      唐山
# 7        180        202      呼和浩特       一般节点   36272      247      太原
# 8        180        272      呼和浩特       一般节点    3443      316      青岛
# 9        474        614       哈尔滨       一般节点    3227      724      济南
# 10       474       1238       哈尔滨       一般节点    1756     1008      北京
# 11       474       1410       哈尔滨       一般节点    4069     1205      宁波
# 12       591         56        绥化       一般节点   36036       52      长春
# 13       591        586        绥化       一般节点     180      192    呼和浩特
# 14       591       1290        绥化       一般节点    2194      180      唐山
# 15       787        324        玉溪       一般节点    1536     1941      广州
# 16        47        243        通辽       一般节点    3213      562      重庆
# 17        63          6        通辽       一般节点    2841      418      郑州
# 18        63        228        通辽       一般节点    1536      398      广州
# 19        96        114      呼和浩特       一般节点    4561     1086      成都
# 20        96        156      呼和浩特       一般节点    4561     1031      成都
# 21        96        460      呼和浩特       一般节点    2050      313     石家庄
# 22       180         50      呼和浩特       一般节点      96      460    呼和浩特
# 23       180        214      呼和浩特       一般节点    1257      576      上海
# 24       474        359       哈尔滨       一般节点    1756      594      北京
# 25       474        475       哈尔滨       一般节点    2473      941      吉林
# 26       474       1228       哈尔滨       一般节点      96      134    呼和浩特
# 27       474       1410       哈尔滨       一般节点   36036       54      长春
# 28       591         56        绥化       一般节点   36422      230      天津
# 29       591        586        绥化       一般节点   36422      124      天津
# 30       591       1274        绥化       一般节点    1997      250      天津
# 31       787        307        玉溪       一般节点   36422      258      天津
# 32        47        240        通辽       一般节点     235     1661      北京
# 33        47        314        通辽       一般节点     591      586      绥化
# 34        47        314        通辽       一般节点    1756     1008      北京
# 35        63         66        通辽       一般节点    4069     1205      宁波
# 36        96        102      呼和浩特       一般节点   36036       52      长春
# 37        96        141      呼和浩特       一般节点    3213      246      重庆
# 38       180        264      呼和浩特       一般节点    1129      546      上海
# 39     36539       1140        杭州       一般节点    3227      781      济南
# 40      2473       1043        吉林       一般节点   36422      324      天津
# 41      3757        122        福州       一般节点      96      407    呼和浩特
# 42       591         23        绥化       一般节点     180      218    呼和浩特
# 43        47        252        通辽       一般节点     474     1389     哈尔滨
# 44      4069       1196        宁波       一般节点     591     1290      绥化
# 45        47        242        通辽       一般节点      47      242      通辽
# 46       180        192      呼和浩特       一般节点      47      249      通辽
# 47        63          6        通辽       一般节点    2701      135      大连
# 48       180        264      呼和浩特       一般节点   36036       54      长春
# 49     36539       1140        杭州       一般节点     235     1661      北京
#
#    to_level      traffic     bandwidth
# 0      一般节点  50492573662  1.000000e+11
# 1      网络核心  50796899329  1.000000e+11
# 2      网络核心  50364636480  1.000000e+11
# 3      网络核心  48210462086  1.000000e+11
# 4      一般节点  49429192047  1.000000e+11
# 5      一般节点  51570663870  1.000000e+11
# 6      网络核心  50973267302  1.000000e+11
# 7      网络核心  49867223584  1.000000e+11
# 8      网络核心  52854391127  1.000000e+11
# 9      网络核心  51504522549  1.000000e+11
# 10     网络核心  51270474683  1.000000e+11
# 11     一般节点  46523775334  1.000000e+11
# 12     一般节点  48627355195  1.000000e+11
# 13     一般节点  49061517661  1.000000e+11
# 14     网络核心  49758461056  1.000000e+11
# 15     网络核心  48712502205  1.000000e+11
# 16     网络核心  49512830312  1.000000e+11
# 17     网络核心  51392218854  1.000000e+11
# 18     网络核心  50443480874  1.000000e+11
# 19     网络核心  49729944227  1.000000e+11
# 20     网络核心  50272713910  1.000000e+11
# 21     网络核心  50175772267  1.000000e+11
# 22     一般节点  49427879868  1.000000e+11
# 23     网络核心  52204574667  1.000000e+11
# 24     网络核心  49659526739  1.000000e+11
# 25     一般节点  49402590822  1.000000e+11
# 26     一般节点  51278220999  1.000000e+11
# 27     一般节点  49488245045  1.000000e+11
# 28     网络核心  47741796615  1.000000e+11
# 29     网络核心  50282882315  1.000000e+11
# 30     网络核心  50278361522  1.000000e+11
# 31     网络核心  51727332383  1.000000e+11
# 32     网络核心  49873119534  1.000000e+11
# 33     一般节点  50043006782  1.000000e+11
# 34     网络核心  49136293957  1.000000e+11
# 35     一般节点  48141568100  1.000000e+11
# 36     一般节点  49483965391  1.000000e+11
# 37     网络核心  47941844052  1.000000e+11
# 38     网络核心  50207994896  1.000000e+11
# 39     网络核心  49721314562  1.000000e+11
# 40     网络核心  50594312992  1.000000e+11
# 41     一般节点  47597054356  1.000000e+11
# 42     一般节点  50522034278  1.000000e+11
# 43     一般节点  51228405663  1.000000e+11
# 44     一般节点  48726638175  1.000000e+11
# 45     一般节点  49820071586  1.000000e+11
# 46     一般节点  50233070000  1.000000e+11
# 47     网络核心  50680536460  1.000000e+11
# 48     一般节点  49124032697  1.000000e+11
# 49     网络核心  51411580502  1.000000e+11

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data = pd.read_csv("C://Users//33566//Desktop//大数据实践//data.csv", encoding='gbk')
# primitive_data

primitive_data_1 = primitive_data.dropna(how='any')
# primitive_data_1

data_before_filter = primitive_data_1
data_after_filter_1 = data_before_filter.loc[data_before_filter["traffic"] != 0]
data_after_filter_2 = data_after_filter_1.loc[data_after_filter_1["from_level"] == '一般节点']
# data_after_filter_2
data_before_sample = data_after_filter_2


def cluster_sampling(data, cluster_column, n_clusters=None, cluster_ratio=None, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
    
    unique_clusters = data[cluster_column].unique()
    total_clusters = len(unique_clusters)
    if n_clusters is not None:
        sample_n = min(n_clusters, total_clusters)
    elif cluster_ratio is not None:
        sample_n = max(1, int(total_clusters * cluster_ratio))
    else:
        sample_n = max(1, int(total_clusters * 0.3))
    selected_clusters = np.random.choice(unique_clusters, size=sample_n, replace=False)
    sampled_data = data[data[cluster_column].isin(selected_clusters)].copy()
    return sampled_data, selected_clusters

possible_cluster_columns = ['to_level', 'from_id', 'to_id']  

cluster_column = None
for col in possible_cluster_columns:
    if col in data_before_sample.columns:
        cluster_column = col
        break


clustered_sample_1, selected_clusters_1 = cluster_sampling(
    data_before_sample, 
    cluster_column, 
    n_clusters=5, 
    random_state=42
)


clustered_sample_2, selected_clusters_2 = cluster_sampling(
    data_before_sample, 
    cluster_column, 
    cluster_ratio=0.3, 
    random_state=42
)

# clustered_sample_1


clustered_sample_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# 5           47        243        通辽       一般节点      96      124    呼和浩特
# 7           47        250        通辽       一般节点    2473      762      吉林
# 9           47        252        通辽       一般节点      96      134    呼和浩特
# 13          47        314        通辽       一般节点      96      152    呼和浩特
# ...        ...        ...       ...        ...     ...      ...     ...
# 1057        47        243        通辽       一般节点    2473      769      吉林
# 1063        47        314        通辽       一般节点      47      252      通辽
# 1079        63        224        通辽       一般节点    4069     1196      宁波
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1104        63          6        通辽       一般节点   36036       20      长春
#
#      to_level      traffic     bandwidth
# 4        一般节点  50492573662  1.000000e+11
# 5        一般节点  49942713747  1.000000e+11
# 7        一般节点  49108721007  1.000000e+11
# 9        一般节点  50256475808  1.000000e+11
# 13       一般节点  50161220081  1.000000e+11
# ...       ...          ...           ...
# 1057     一般节点  49117847542  1.000000e+11
# 1063     一般节点  49900452417  1.000000e+11
# 1079     一般节点  50209459772  1.000000e+11
# 1097     一般节点  48409925693  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
#
# [186 rows x 10 columns]
